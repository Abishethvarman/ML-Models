# %% [markdown]
# <a href="https://colab.research.google.com/github/Abishethvarman/ML-Models/blob/main/saroth_NFR_Linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A false approach

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %cd /mydrive/dataset/

# %%
import pandas as pd
import nltk
import torch
import numpy as np
import matplotlib.pyplot as plt
import string
from gensim.corpora import Dictionary
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("saroth.csv")

# %%
data
# Out:
#     Type                                        Requirement
# 0     PE  The system shall refresh the display every 60 ...
# 1     LF  The application shall match the color of the s...
# 2     US   If projected  the data must be readable.  On ...
# 3      A   The product shall be available during normal ...
# 4     US   If projected  the data must be understandable...
# ..   ...                                                ...
# 797   SE  User access should be limited to the permissio...
# 798   LF  The product must comply with the intranet page...
# 799   LF  The intranet pages should display appropriatel...
# 800   US  The users should be able to easily use the sys...
# 801   PE  The product interface should be fast. The resp...
#
# [802 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
data['Type'].plot(kind='hist', bins=20, title='Type')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['Type'].plot(kind='line', figsize=(8, 4), title='Type')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
row_count = data.shape[0]
print("Total inputs:", row_count)
# Out:
# Total inputs: 802

# %%
data['Type'] = data['Type'].replace({
    'LF': 0,
    'PE': 1,
    'PO': 2,
    'SE': 3,
    'US': 4,
    'PR': 5,
    'MN': 6,
    'SC': 7,
    'ER': 8,
    'A': 9,
    'FT': 10,
    'L': 11,
    'O': 12,
    'NFR':13
    })

# %%
data
# Out:
#      Type                                        Requirement
# 0       1  The system shall refresh the display every 60 ...
# 1       0  The application shall match the color of the s...
# 2       4   If projected  the data must be readable.  On ...
# 3       9   The product shall be available during normal ...
# 4       4   If projected  the data must be understandable...
# ..    ...                                                ...
# 797     3  User access should be limited to the permissio...
# 798     0  The product must comply with the intranet page...
# 799     0  The intranet pages should display appropriatel...
# 800     4  The users should be able to easily use the sys...
# 801     1  The product interface should be fast. The resp...
#
# [802 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
from matplotlib import pyplot as plt
data['Type'].plot(kind='hist', bins=20, title='Type')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
X = data['Type'].values.reshape(-1, 1)
y = data['Type'].values ==3

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

plt.scatter(X_test, y_test, color='b')
plt.plot(X_test, y_pred, color='r', linewidth=2)
plt.xlabel('Type')
plt.ylabel('Non Functional Requirement')
plt.title('Linear Regression for nonFunctionl requirements')
plt.show()
# Out:
# Mean Squared Error: 0.10103748700604563
